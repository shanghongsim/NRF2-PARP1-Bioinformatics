# %%
import numpy as np # scientific computing
import pandas as pd # data loading and processing
import os # os operations
import matplotlib.pyplot as plt # for generating figures
import math
import matplotlib.dates as mdates
import seaborn as sns # for generating visualizations, better support with pandas than matplotlib
from scipy import stats

import csv

# %%
def construct_filename(c, db):
    if db =="xena":
        n1 = "./data/" + "TCGA." + c + ".sampleMap_HiSeqV2"
        n2 = "./data/" + "TCGA." + c + ".sampleMap_"+ c +"_clinicalMatrix"
    elif db == "cbio":
        n1 = "./data/" + c+"_data_mrna_seq_v2_rsem.txt"
        n2 = "./data/" + c + "_data_clinical_sample.txt"
    else:
        print("db must be either xena or cbio")
    return n1,n2

def construct_hccdb_filename(n):
    n1 = "./data/HCCDB/HCCDB" + n + "_mRNA_level3.txt"
    n2 = "./data/HCCDB/HCCDB" + n  + ".sample.txt"
    return n1,n2

def get_xena_data(n1):
    df = pd.read_csv(n1, index_col = 0, sep = "\t") # gene x patient
    return df

def get_cbio_data(n1):
    df = pd.read_csv(n1, index_col = 0, sep = "\t").drop(["Entrez_Gene_Id"], axis=1) # gene x patient
    return df

def get_hccdb_data(n1):
    df = pd.read_csv(n1, index_col = 1, sep = "\t").drop(["Entrez_ID"], axis=1) # gene x patient
    return df


def get_xena_pheno(n2):
    pheno = pd.read_csv(n2, index_col=0, sep = "\t")
    pheno = pheno[["sample_type"]]
    pheno_filtered = pheno.dropna()
    return pheno_filtered

def get_cbio_pheno(n2):
    pheno = pd.read_csv(n2, index_col=1,header = 4, sep = "\t")
    pheno = pheno[["SAMPLE_TYPE"]]
    pheno_filtered = pheno.dropna()
    return pheno_filtered

def get_hccdb_pheno(n2):
    pheno = pd.read_csv(n2, index_col=0, sep = "\t").T
    pheno = pheno[["TYPE"]]
    pheno_filtered = pheno.dropna()
    return pheno_filtered

def process_data(df, targets, y_var_names, pheno_filtered=None):

    # subset to get relevant genes
    df_filtered = df.loc[targets]

    # patients x genes
    df_filtered = df_filtered.T 
    
    # scale numerical data
    df_filtered = np.log10(df_filtered+1)

    # for each sequenced gene were rescaled to set the median equal to 1
    df_filtered=((df_filtered-df_filtered.median())/df_filtered.std())+1

    # check for nan values
    na_filter = df_filtered.isnull().any()
    na_ls = na_filter[na_filter == True].index.to_list()
    # print(na_ls)
    
    # impute nan values
    df_filtered = df_filtered.T # genes x patients
    mean_ls = df_filtered.mean()
    for na_col in na_ls:
        df_filtered[na_col] = df_filtered[na_col].fillna(mean_ls[na_col])
    # print(df_filtered.isnull().values.any())
    df_filtered = df_filtered.T # patients x genes

    # add sample type labels
    if pheno_filtered is not None:
        data = pd.concat([df_filtered, pheno_filtered], axis = 1, join='inner')

    # take only nrf2 target genes
    y_var_gene_set = data[y_var_names]
    data.drop(y_var_names, inplace = True, axis = 1)
    y_var_gene_set["composite_score"] = y_var_gene_set.mean(axis = 1)
    data = pd.concat([data, y_var_gene_set], axis = 1) # patients x genes 

    return data

def analyse(data, fig, axs, cancer, c, fn, x_target = "RRM2B", y_target = "composite_score"):
    #find line of best fit
    y, x = data[y_target].to_numpy(), data[x_target].to_numpy()
    a, b = np.polyfit(x, y, 1)

    iqr = data[x_target].T.describe()

    # bin the patients into quartiles based on G6PD expression
    data["RRM2B levels"] = pd.cut(data["RRM2B"],
                    bins=[ iqr["min"], iqr["25%"], iqr["75%"], iqr["max"]],
                    labels=["Bottom 25%", "-", "Top 25%"])

    # get r sq val
    r = np.corrcoef(x, y)[0, 1]

    #find p-value
    n = data.shape[0]
    t = (r-math.sqrt(n-2))/math.sqrt(1-(r**2))
    p = stats.t.sf(abs(t), df=n)*2

    # plot the data

    # scatter plot for RRM2B against NRF2 activity
    sns.set_style("whitegrid")
    sns.set()
    sns.scatterplot(data=data, x=x_target, y=y_target, ax= axs[cancer.index(c)])
    axs[cancer.index(c)].plot(x, a*x+b, color="black")
    axs[cancer.index(c)].set_ylabel("NRF2 activity (based on 53 genes)",fontsize = 18)
    axs[cancer.index(c)].set_xlabel("RRM2B expression" + " \n (r = " + str(round(r, 4)) + "," + " p = " + str(round(p, 4)) +")",rotation=10,fontsize = 15)
    axs[cancer.index(c)].set_title(cancer[cancer.index(c)], fontsize = 20)
    axs[cancer.index(c)].tick_params(axis='both', which='major', labelsize=15)
    plt.show()

    # save the figure 
    fig.savefig(fn)

def get_targets_present(data, targets):
    idx = data.index.to_list()
    # print(idx)
    # print(targets)
    targets_present = list(set(idx).intersection(set(targets)))
    # print(targets_present)
    return targets_present

# %%
# script o sort all TCGA data into low vs high p53 status

# load all data and concatenate it into one dataframe

hccdb = ["1", "3", "4",  "8", "9", "11", "12", "13", "14", "15", "16", "17", "18"]
tcga = ["COADREAD", "HNSC", "KIRC", "LUAD", "LIHC", "LUSC", "OV", "BRCA"] # , , "PANCAN"
db_names= [hccdb, tcga]
df = pd.DataFrame()

for i in range(len(db_names)):
    for j in range(len(db_names[i])):
        print(db_names[i][j])
        if i == 0:
            n1, n2 = construct_hccdb_filename(db_names[i][j])
            df_temp = get_hccdb_data(n1)
            # print(df_temp.head())
        else:
            n1, n2 = construct_filename(db_names[i][j], "xena")
            df_temp = get_xena_data(n1)
            # print(df_temp.head())
        df_temp = df_temp.loc[~df_temp.index.duplicated(),:].copy()
        df = pd.concat([df, df_temp], axis = 1) # patients x genes

# %%
# script to sort all data into low vs high RRM2B status

hccdb = ["1", "3", "4",  "8", "9", "11", "12", "13", "14", "15", "16", "17", "18"]
tcga = ["COADREAD", "HNSC", "KIRC", "LUAD", "LIHC", "LUSC", "OV", "BRCA"] # , , "PANCAN"
db_names= [hccdb, tcga]
df = pd.DataFrame()

for i in range(len(db_names)):
    for j in range(len(db_names[i])):
        print(db_names[i][j])

        # get data
        if i == 0:
            n1, n2 = construct_hccdb_filename(db_names[i][j])
            df_temp = get_hccdb_data(n1)
            # print(df_temp.head())
        else:
            n1, n2 = construct_filename(db_names[i][j], "xena")
            df_temp = get_xena_data(n1)
            # print(df_temp.head())
        
        # df_temp = df_temp.loc[~df_temp.index.duplicated(),:].copy()
        # df = pd.concat([df, df_temp], axis = 1) # patients x genes
        df = df_temp
        df = df.T

        # bin the patients into quartiles based on RRM2B expression
        iqr = df["RRM2B"].describe()
        df["RRM2B_levels"] = pd.cut(df["RRM2B"],
                        bins=[ iqr["min"], iqr["25%"], iqr["75%"], iqr["max"]],
                        labels=["Bottom 25%", "-", "Top 25%"])
        df.drop(df.loc[df["RRM2B_levels"]=="-"].index, inplace=True)

        top = df[df["p53 levels"] == "Top 25%"]["p53 exp"]
        bottom = df[df["p53 levels"] == "Bottom 25%"]["p53 exp"]

# %%
# script to find genes with log fold change >= 0.32

hccdb = ["1", "3", "4",  "8", "9", "11", "12", "13", "14", "15", "16", "17", "18"]
tcga = ["COADREAD", "HNSC", "KIRC", "LUAD", "LIHC", "LUSC", "OV", "BRCA"] # , , "PANCAN"
db_names= [tcga]
df = pd.DataFrame()
# overlap = set()

with open('tcga log fold change.csv', 'w') as f:
    
    write = csv.writer(f)

    for i in range(len(db_names)):
        for j in range(len(db_names[i])):
            print(db_names[i][j])

            # # get data
            # if i == 0:
            #     n1, n2 = construct_hccdb_filename(db_names[i][j])
            #     df_temp = get_hccdb_data(n1)
                
            # else:
            #     n1, n2 = construct_filename(db_names[i][j], "xena")
            #     df_temp = get_xena_data(n1)
            
            n1, n2 = construct_filename(db_names[i][j], "xena")
            df_temp = get_xena_data(n1)
            
            df = df_temp
            df = df.T # patients x genes

            # print("total number of genes: ", str(len(df.columns.to_list())))

            # bin the patients into quartiles based on RRM2B expression
            iqr = df["RRM2B"].describe()
            df["RRM2B_levels"] = pd.cut(df["RRM2B"],
                            bins=[ iqr["min"], iqr["25%"], iqr["75%"], iqr["max"]],
                            labels=["Bottom 25%", "-", "Top 25%"])
            df.drop(df.loc[df["RRM2B_levels"]=="-"].index, inplace=True)

            high = df[df["RRM2B_levels"] == "Top 25%"]
            low = df[df["RRM2B_levels"] == "Bottom 25%"]

            high.drop("RRM2B_levels", axis = 1, inplace=True)
            low.drop("RRM2B_levels", axis = 1, inplace=True)

            high.loc["mean high"] = high.mean()
            low.loc["mean low"] = low.mean()

            combined = pd.concat([high.loc[["mean high"]], low.loc[["mean low"]]])
            diff = combined.loc["mean high"]-combined.loc["mean low"]
            output = diff.loc[diff.abs() >= 0.32].index.to_list()

            if i == 0 and j == 0:
                overlap = set(output)
            
            overlap = overlap.intersection(set(output))
            print(list(overlap))

            # print("number of genes differentially expressed: ", len(output))
            print("---------")
            output = [db_names[i][j]] + output
            write.writerow(output)
# Out:
# COADREAD
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high.drop("RRM2B_levels", axis = 1, inplace=True)
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low.drop("RRM2B_levels", axis = 1, inplace=True)
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high.loc["mean high"] = high.mean()
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low.loc["mean low"] = low.mean()
# ['INE2', 'ANKS6', 'GPA33', 'QPRT', 'CCR4', 'DARC', 'ACTR10', 'EML1', 'LONRF2', 'KIF24', 'EPHB3', 'MAF', 'ACRBP', 'ADH1C', 'SCAMP1', 'PACRG', 'RASSF5', 'TCP11L2', 'UBE2E2', 'CCNG2', 'C9orf69', 'MMRN2', 'HBA1', 'ANPEP', 'FCGR3B', 'CEACAM3', 'RGS10', 'NR3C1', 'ABCC3', 'CORO2B', 'LOC100132287', 'ZNF300', 'DCC', 'CENPT', 'WIF1', 'FCER1A', 'ENTHD1', 'CAMKV', 'CD22', 'SEMA3D', 'DDX39', 'MR1', 'LOC285954', 'C2orf70', 'PLIN4', 'CD300LB', 'TNFRSF6B', 'SLC31A2', 'DCLK2', 'NFKBID', 'LYSMD3', 'CDC7', 'PDZRN4', 'NCLN', 'TNNC1', 'EPHX3', 'EPHB2', 'TNFAIP8L2', 'PLCB4', 'KL', 'GBP1', 'GABBR1', 'GABPA', 'AKAP3', 'OLFM1', 'C4orf34', 'TMEM211', 'IRAK3', 'PRPH2', 'HRH2', 'C20orf134', 'IL21R', 'SALL2', 'NTF3', 'NOTUM', 'CD163', 'GLI2', 'LEF1', 'C20orf165', 'KITLG', 'EBAG9', 'ACER2', 'MFAP3L', 'INCENP', 'ENPEP', 'BCAN', 'FAM150A', 'GPM6A', 'A2M', 'HKDC1', 'NLRP9', 'MMP10', 'OMP', 'ZNF483', 'CRYGS', 'LRRC8C', 'SCG3', 'LOC153328', 'PHLDA3', 'PIK3AP1', 'GGT5', 'PI15', 'TRPM8', 'PPAPDC1A', 'CCL3', 'IVL', 'NCRNA00173', 'MGC16384', 'CCDC17', 'TMEM128', 'MZF1', 'LOC338799', 'ZNF367', 'CTSO', 'EPR1', 'PLSCR3', 'DRD1', 'CDX2', 'PRODH', 'ART3', 'SPAG1', 'FPR3', 'FAM174B', 'ALDH16A1', 'HAL', 'CKMT1B', 'SIGLEC6', 'CCDC14', 'GSTM1', 'NACAD', 'ELTD1', 'HCG4P6', 'CDK17', 'KIF3C', 'VAMP5', 'C1QTNF2', 'NBLA00301', 'FCER2', 'HTR2A', 'ELOVL4', 'C9orf172', 'AP1S1', 'UCHL1', 'HOXB9', 'SLC4A4', 'PNRC1', 'TCF3', 'GSTM2', 'SYDE1', 'GPRC5B', 'WISP2', 'FAM190A', 'CEND1', 'SERPINI1', 'LOC100132724', 'ELOVL3', 'CHST9', 'MVK', 'DOK3', 'C17orf77', 'S1PR3', 'HAND2', 'COL6A3', 'ZBTB47', 'SDR16C5', 'MAMLD1', 'SEPT5', 'LAPTM5', 'C4orf31', 'TNFRSF11A', 'EID1', 'IL27RA', 'ADAMTS12', 'GNS', 'NCAPD2', 'CD74', 'GTSE1', 'MN1', 'FLNA', 'ZNF492', 'BPGM', 'RIMBP3C', 'SMOC2', 'C9orf139', 'C3orf52', 'PLOD2', 'CLEC1A', 'RAVER1', 'HLA-DOB', 'MYOC', 'B3GALT2', 'TMEM59L', 'LRRC15', 'PUS1', 'MSR1', 'CCNJL', 'VAX2', 'GNPDA2', 'GIGYF1', 'SYMPK', 'GPR65', 'FERMT3', 'WDR4', 'AZIN1', 'SLAMF7', 'CD4', 'LOC388152', 'TTBK2', 'SLC9A2', 'FUT7', 'ST3GAL5', 'PRDM1', 'CXCR4', 'GNB5', 'LOC349114', 'CNTN2', 'FHL3', 'HTR7', 'SORL1', 'CHODL', 'C8orf40', 'C2orf27A', 'IGFALS', 'CCR8', 'CCBL1', 'GREB1', 'AIFM3', 'TMEM119', 'CLCNKB', 'C9orf142', 'BCAT1', 'AOC3', 'HS6ST3', 'TCL1A', 'S100A12', 'PCDH11X', 'LRRC17', 'BYSL', 'RAP1A', 'NLRP3', 'ZNF454', 'PVRL1', 'ZFP2', 'C6orf176', 'HMGA2', 'FBXO32', 'TCEAL3', 'ETV4', 'TRMT1', 'DSCR6', 'PARP15', 'UBASH3A', 'CTXN1', 'C7orf41', 'ABCB5', 'ANXA8L2', 'BACE1', 'MRAP2', 'KIAA0664P3', 'PRTG', 'C10orf140', 'PKD2', 'HLA-L', 'PEG10', 'SCN4A', 'GRINL1A', 'ADC', 'PFDN2', 'LIMD2', 'EBF1', 'C5orf46', 'LRP4', 'PTK2', 'IL12RB1', 'CXCL12', 'CDC37', 'ODZ4', 'PHYHIPL', 'PHOX2B', 'KIF20A', 'ANO9', 'STK17B', 'SRPX2', 'DPEP2', 'KLHL7', 'TPSAB1', 'SPSB1', 'SLC1A3', 'PTPRC', 'LOC100240735', 'ANK2', 'ZNF418', 'TRIM54', 'C10orf110', 'VSIG8', 'NEB', 'WDR7', 'LST1', 'COMMD8', 'LAMA4', 'CLEC4G', 'TBRG4', 'SFRS16', 'LOX', 'F13A1', 'UTS2D', 'KIAA1524', 'FGF18', 'FOXO1', 'DNASE1L2', 'NTM', 'ZNF665', 'C1orf133', 'ZWINT', 'C9orf37', 'NR2F6', 'PFDN6', 'RAB37', 'LATS2', 'CD109', 'UPK3BL', 'ADAM32', 'CRYZL1', 'ZNF593', 'LOC440944', 'IRF8', 'GLIS2', 'RNASE6', 'RERGL', 'SPC24', 'CPVL', 'PTCHD1', 'PTGES2', 'FAM22F', 'MGC45800', 'LGALS14', 'C16orf3', 'P4HA3', 'LOC100272228', 'CORT', 'SLAMF1', 'S1PR2', 'TMEM170B', 'LGI4', 'EFCAB1', 'OLFML3', 'EIF3H', 'SFRS17A', 'ODAM', 'NAP1L2', 'ABCG5', 'TCF7L1', 'GLCCI1', 'HTR2B', 'MT1L', 'SH3GL2', 'TLR2', 'PTPRU', 'MPDZ', 'RRBP1', 'GMFG', 'PRSS12', 'ADRB1', 'THSD1P1', 'C19orf71', 'ADAMTS19', 'NME1-NME2', 'SPHKAP', 'SLC26A2', 'CLEC7A', 'HSPA1B', 'H2AFX', 'SYT17', 'SNED1', 'SYT3', 'PPFIBP1', 'AATK', 'TMEM140', 'PPFIA4', 'C1orf150', 'BBS9', 'ZNF396', 'C11orf63', 'JSRP1', 'ZMAT3', 'DIO2', 'GRM5', 'KLF10', 'CORIN', 'TM6SF1', 'MFSD2B', 'MBLAC2', 'ZDHHC2', 'WSCD1', 'SRL', 'SLCO4A1', 'PTPRD', 'ACHE', 'FUT3', 'HIC1', 'ENPP6', 'MERTK', 'GNG4', 'ZNF43', 'NCAPG', 'STAB2', 'STARD8', 'JAKMIP1', 'MAP4K3', 'GSTM5', 'C6orf204', 'SPTLC3', 'C4orf48', 'DNHD1', 'WBSCR17', 'CPZ', 'MEX3B', 'CYSLTR1', 'P ...
# ---------
# HNSC
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high.drop("RRM2B_levels", axis = 1, inplace=True)
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low.drop("RRM2B_levels", axis = 1, inplace=True)
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high.loc["mean high"] = high.mean()
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low.loc["mean low"] = low.mean()
# ['ELK3', 'INE2', 'GUCA1B', 'MYLK3', 'MARVELD1', 'TAOK1', 'KIAA0247', 'MTFR1', 'PRDM8', 'C10orf81', 'GPA33', 'HPSE2', 'CTNNA3', 'CENPM', 'ADAT3', 'PRF1', 'IL17RE', 'ANO1', 'CAPS', 'CCR4', 'RIMS2', 'NUDT1', 'EPB41L3', 'GVIN1', 'ACRC', 'EML1', 'DAZL', 'GOLGA2B', 'LONRF2', 'B3GNT6', 'EPHB3', 'C20orf108', 'KCNJ8', 'DDX43', 'NMNAT2', 'ISLR', 'ST6GALNAC5', 'MAF', 'C21orf34', 'MSH5', 'CXCR5', 'ADH1C', 'UCN', 'IGF2BP1', 'AGL', 'SCAMP1', 'ZNF251', 'SYNM', 'NSUN5P1', 'KCND3', 'CARD10', 'SPSB4', 'NPC1L1', 'IFIT3', 'IL6ST', 'ZNF461', 'C3orf35', 'BMP6', 'MYCN', 'MORN3', 'SCN4B', 'GRM4', 'SYT14', 'DENND5B', 'RASSF5', 'PKIB', 'AGTR1', 'TCP11L2', 'PAG1', 'CHCHD10', 'LGALS9B', 'ZNF385B', 'C9orf69', 'PDZRN3', 'PCDHGB6', 'MMRN2', 'ANPEP', 'PRDM16', 'LILRB1', 'C1orf190', 'ANXA13', 'RHOT2', 'C17orf55', 'SYBU', 'TIGIT', 'CAP2', 'PDE4D', 'NR3C1', 'CORO2B', 'ADCY7', 'LOC100132287', 'TESC', 'DCC', 'CDH15', 'SERPINA5', 'DIRAS1', 'CENPT', 'RECK', 'FCER1A', 'SEC16B', 'ENTHD1', 'DHX40', 'FAM107A', 'ARMCX1', 'CLEC4A', 'BOC', 'SPRY4', 'RTN4RL1', 'DYSF', 'PRSS8', 'THBS1', 'LOC100129637', 'TNFRSF11B', 'C1QTNF7', 'CAPS2', 'CD22', 'SEMA3D', 'DDX39', 'MR1', 'PLXNC1', 'ITGA7', 'PLIN4', 'SLC2A10', 'SERPINA3', 'CD300LB', 'PRIMA1', 'ASAM', 'RPSAP52', 'TP53INP1', 'C19orf6', 'DCLK2', 'PCDHGA12', 'CD1B', 'CUBN', 'ECM2', 'KLHL28', 'PTPLAD2', 'LYSMD3', 'AMZ1', 'ARHGEF17', 'PDZRN4', 'NCLN', 'EPAS1', 'CDYL2', 'ZMYND12', 'TNNC1', 'DDIT4L', 'ASAP1', 'MT1A', 'EPHX3', 'LASS4', 'UBASH3B', 'C7orf58', 'DKK3', 'HOXD11', 'GSDMB', 'PLCB4', 'KL', 'TIFAB', 'GBP1', 'CDC42EP5', 'PHOSPHO1', 'MOBKL1A', 'GLT8D2', 'AKAP3', 'GABPA', 'OLFM1', 'MARCH8', 'ITGAD', 'LOC150776', 'EIF4E3', 'WDR72', 'ZNF843', 'C4orf34', 'TMEM132B', 'TCP11', 'NAV1', 'NTS', 'CDH5', 'ANKS1B', 'TMEM65', 'IRAK3', 'SDS', 'PRPH2', 'CD300LF', 'HRH2', 'LOC100133669', 'CD93', 'C20orf134', 'IL21R', 'TBXAS1', 'SALL2', 'CD163', 'GINS2', 'LEF1', 'NRG2', 'KITLG', 'EBAG9', 'SYPL2', 'NIPAL2', 'MAZ', 'ACER2', 'PGR', 'MFAP3L', 'JAM3', 'CRYBB2', 'ENPEP', 'RASL12', 'LILRB2', 'BCAN', 'CLIC4', 'LOC100288778', 'SIX1', 'DRAM1', 'GPM6A', 'PTN', 'TELO2', 'TMEM54', 'DACT3', 'STK33', 'KCNS1', 'ATP2A1', 'LOC255167', 'DUOXA1', 'PGCP', 'A2M', 'ARHGAP15', 'PPDPF', 'LLGL2', 'MTTP', 'HKDC1', 'FEN1', 'NLRP9', 'P2RY11', 'EIF2C4', 'MMP10', 'PLA2G2D', 'EBF2', 'ADSSL1', 'C2CD4D', 'CD207', 'LOC643763', 'NFATC2', 'CRYGS', 'PCDHB3', 'UBL3', 'ID1', 'FRMPD4', 'SLC9A7', 'LRRC8C', 'ZFP37', 'SCG3', 'CENPH', 'FAM173A', 'KCNJ10', 'LOC153328', 'OTUD6B', 'MUSK', 'MND1', 'PIK3AP1', 'MS4A1', 'PI15', 'SIGLEC14', 'SPP1', 'PPAPDC1A', 'HLA-DMB', 'CNTFR', 'AMPD1', 'IVL', 'MAGEA12', 'UBXN11', 'STEAP4', 'CKMT2', 'GLIPR2', 'MGC16384', 'CCDC17', 'FAP', 'TWIST1', 'APOBEC3C', 'PPP1R9A', 'C17orf86', 'LOC338799', 'SLIT3', 'CDH11', 'CTSO', 'SOS2', 'UGT1A10', 'LILRA4', 'FGF2', 'CDON', 'GRID1', 'DRD1', 'LTBP2', 'PRODH', 'RGS7BP', 'KCNN2', 'PILRA', 'ART3', 'VSIG2', 'C18orf1', 'AQP6', 'SPAG1', 'FPR3', 'GPR88', 'ZNF702P', 'CCRL1', 'HAL', 'FCHO2', 'PTPRT', 'KIAA1199', 'LOC100190938', 'CKMT1B', 'SIGLEC6', 'psiTPTE22', 'HIP1R', 'ZCWPW2', 'ADAM23', 'FAM129A', 'ADAMTS10', 'CCR2', 'PAR5', 'PIWIL1', 'ELTD1', 'CTBS', 'CDK17', 'ATP6V0D2', 'C1QTNF2', 'NAV3', 'CRTAC1', 'NDP', 'NBLA00301', 'GEM', 'LRRC4C', 'TAGAP', 'HTR2A', 'PDE1B', 'KIAA1429', 'MNDA', 'CHRNA1', 'C9orf172', 'CCDC110', 'MKX', 'CST7', 'MRPL55', 'RBM24', 'COL6A2', 'CDKN2B', 'PPM1L', 'HOXB9', 'SLC4A4', 'PNRC1', 'ANO6', 'ZNF787', 'RPL39L', 'GLIPR1', 'NOP16', 'GPRC5B', 'SPOCK1', 'GMPR', 'PPFIA3', 'WISP2', 'FAM190A', 'CADM1', 'ALKBH6', 'MBNL2', 'CALCR', 'APOBEC3G', 'MYOZ1', 'NDUFS7', 'SMURF2', 'GRIP1', 'CDC42EP3', 'C12orf59', 'CXCL3', 'INPP5D', 'SLC2A5', 'FGF5', 'MVK', 'DOK3', 'CACNG1', 'S1PR3', 'HAND2', 'COL6A3', 'ZBTB47', 'ATP8B2', 'SGTB', 'EPM2A', 'C3AR1', 'B4GALNT1', 'CCR3', 'LAPTM5', 'SH3RF3', 'MRPL41', 'CSPP1', 'MMP16', 'ARC', 'PGM5P2', 'RRAGC', 'NTNG1', 'THRB', 'C10orf128', 'C4orf31', 'TNFRSF11A', 'EID1', 'VEPH1', 'IL27RA', 'WNT11', 'ADAMTS12', 'IL2RB', 'PCDHGA3', 'HFM1', 'C11orf92', 'CCDC89', 'FREM1', 'GNS', 'ABCA6', 'EDN3', 'PRSS21 ...
# ---------
# KIRC
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high.drop("RRM2B_levels", axis = 1, inplace=True)
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low.drop("RRM2B_levels", axis = 1, inplace=True)
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high.loc["mean high"] = high.mean()
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low.loc["mean low"] = low.mean()
# ['INE2', 'GUCA1B', 'TAOK1', 'PRDM8', 'MTFR1', 'C10orf81', 'CENPM', 'ADAT3', 'PRF1', 'ANO1', 'RIMS2', 'NUDT1', 'ACRC', 'GOLGA2B', 'LONRF2', 'KCNJ8', 'ST6GALNAC5', 'MAF', 'C21orf34', 'MSH5', 'CXCR5', 'ADH1C', 'UCN', 'AGL', 'SCAMP1', 'ZNF251', 'NSUN5P1', 'KCND3', 'CARD10', 'SPSB4', 'IL6ST', 'C3orf35', 'MYCN', 'BMP6', 'SCN4B', 'SYT14', 'PKIB', 'AGTR1', 'TCP11L2', 'CHCHD10', 'ZNF385B', 'C9orf69', 'ANPEP', 'PRDM16', 'LILRB1', 'C1orf190', 'ANXA13', 'RHOT2', 'C17orf55', 'SYBU', 'TIGIT', 'NR3C1', 'LOC100132287', 'SERPINA5', 'DIRAS1', 'CENPT', 'SEC16B', 'BOC', 'SPRY4', 'RTN4RL1', 'DYSF', 'PRSS8', 'LOC100129637', 'TNFRSF11B', 'CAPS2', 'DDX39', 'MR1', 'PLXNC1', 'ITGA7', 'PLIN4', 'SERPINA3', 'CD300LB', 'ASAM', 'C19orf6', 'DCLK2', 'CUBN', 'PTPLAD2', 'LYSMD3', 'AMZ1', 'ARHGEF17', 'PDZRN4', 'NCLN', 'EPAS1', 'CDYL2', 'DDIT4L', 'TNNC1', 'UBASH3B', 'GSDMB', 'KL', 'TIFAB', 'GBP1', 'CDC42EP5', 'MOBKL1A', 'GLT8D2', 'AKAP3', 'MARCH8', 'LOC150776', 'EIF4E3', 'WDR72', 'C4orf34', 'CDH5', 'TMEM65', 'SDS', 'CD300LF', 'LOC100133669', 'C20orf134', 'IL21R', 'SALL2', 'CD163', 'KITLG', 'NIPAL2', 'MAZ', 'ACER2', 'PGR', 'MFAP3L', 'JAM3', 'CRYBB2', 'ENPEP', 'RASL12', 'LILRB2', 'LOC100288778', 'SIX1', 'PTN', 'TELO2', 'TMEM54', 'DACT3', 'STK33', 'KCNS1', 'ATP2A1', 'LOC255167', 'ARHGAP15', 'PPDPF', 'MTTP', 'NLRP9', 'P2RY11', 'ADSSL1', 'CD207', 'NFATC2', 'CRYGS', 'SLC9A7', 'UBL3', 'ID1', 'FAM173A', 'KCNJ10', 'OTUD6B', 'MND1', 'PIK3AP1', 'MS4A1', 'PI15', 'SPP1', 'PPAPDC1A', 'CNTFR', 'IVL', 'MAGEA12', 'UBXN11', 'CKMT2', 'GLIPR2', 'MGC16384', 'CCDC17', 'TWIST1', 'PPP1R9A', 'C17orf86', 'LOC338799', 'SLIT3', 'CTSO', 'SOS2', 'FGF2', 'CDON', 'GRID1', 'RGS7BP', 'PRODH', 'PILRA', 'VSIG2', 'AQP6', 'GPR88', 'ZNF702P', 'FCHO2', 'KIAA1199', 'CKMT1B', 'psiTPTE22', 'ZCWPW2', 'ADAMTS10', 'PAR5', 'CTBS', 'ATP6V0D2', 'C1QTNF2', 'CRTAC1', 'NDP', 'LRRC4C', 'PDE1B', 'KIAA1429', 'CHRNA1', 'C9orf172', 'CST7', 'MRPL55', 'COL6A2', 'CDKN2B', 'PPM1L', 'HOXB9', 'SLC4A4', 'ANO6', 'ZNF787', 'NOP16', 'GPRC5B', 'SPOCK1', 'GMPR', 'PPFIA3', 'WISP2', 'FAM190A', 'CADM1', 'ALKBH6', 'MBNL2', 'APOBEC3G', 'MYOZ1', 'NDUFS7', 'GRIP1', 'C12orf59', 'SLC2A5', 'DOK3', 'HAND2', 'COL6A3', 'ATP8B2', 'EPM2A', 'B4GALNT1', 'SH3RF3', 'MRPL41', 'MMP16', 'RRAGC', 'THRB', 'C10orf128', 'C4orf31', 'TNFRSF11A', 'VEPH1', 'IL27RA', 'ADAMTS12', 'IL2RB', 'FREM1', 'GNS', 'ABCA6', 'EDN3', 'MN1', 'CD74', 'FLNA', 'MYOZ3', 'PRDM6', 'ELF5', 'MAP3K12', 'CCDC19', 'IGSF10', 'TLR6', 'CEMP1', 'ZNF683', 'SMOC2', 'HLA-DRB6', 'CD68', 'CLEC1A', 'DOC2B', 'EYA2', 'STON1-GTF2A1L', 'BACH1', 'PPP1R14D', 'FAM92A1', 'LPIN3', 'NTHL1', 'ZNF660', 'SCN3B', 'MCTP1', 'SPI1', 'PUS1', 'MSR1', 'VAX2', 'GNPDA2', 'LMOD3', 'FLJ45244', 'FERMT3', 'DUS1L', 'OSGIN1', 'WDR85', 'AZIN1', 'LCN2', 'SLAMF7', 'TTBK2', 'SLC9A2', 'SECISBP2L', 'S100A8', 'CXCR4', 'DENND2C', 'CCL2', 'ARRDC3', 'PEG3', 'RPL36A', 'TTLL7', 'VIM', 'C2orf89', 'SORL1', 'KCND2', 'ATP8B4', 'SYT9', 'BAG4', 'CCBL1', 'GREB1', 'C9orf142', 'AHSA2', 'TCL1A', 'CHSY3', 'OR51E2', 'S100A12', 'HOMER3', 'KLK1', 'LRRC17', 'COL8A1', 'MAN1C1', 'BYSL', 'EPDR1', 'BGN', 'XRN1', 'LAP3', 'CHRD', 'IL10RA', 'PPM1A', 'IRS1', 'HMGA2', 'PHACTR1', 'C8orf31', 'FMOD', 'TMEM130', 'FBXO32', 'NRXN2', 'ENPP1', 'ALDH3A1', 'TRMT1', 'EME1', 'ARL4D', 'PCDHGB1', 'PARP15', 'UBASH3A', 'TNFRSF25', 'CNRIP1', 'SETBP1', 'COL22A1', 'SCARNA12', 'CLIP4', 'LILRA5', 'TSHZ2', 'FAM184B', 'ADAMTSL1', 'PQLC3', 'FAM168A', 'FLT3', 'PRTG', 'FOXF1', 'ANKRD23', 'CASD1', 'BRMS1L', 'SUSD2', 'PKD2', 'POLE', 'SCN4A', 'GRINL1A', 'GPR172B', 'ADC', 'C1orf35', 'PFDN2', 'HEYL', 'SFTA1P', 'LOC653501', 'IDO1', 'EBF1', 'LGI3', 'IL12RB1', 'MAPK4', 'AMY2B', 'CDC37', 'ODZ4', 'PILRB', 'KLHL14', 'UGT1A7', 'PHYHIPL', 'ZNF90', 'WASH5P', 'TREX1', 'FCER1G', 'HRAS', 'TTC28', 'ANO9', 'SIRT6', 'C6orf186', 'TRIM9', 'PSMG3', 'FXYD1', 'COL21A1', 'TPSAB1', 'ZNF831', 'CPEB4', 'SELE', 'ANK2', 'FAM19A2', 'RELL2', 'FZD6', 'MRPL14', 'HP', 'C9orf140', 'TRIM54', 'VSIG8', 'DCDC2', 'LSM7', 'NEB', 'SKA1', 'WDR7', 'CYP2D7P1', 'TMEM155', 'GREB1L', 'LAMA4', 'FAM161B', 'STAU2', 'DCAF12L2', 'RHOH', ' ...
# ---------
# LUAD
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high.drop("RRM2B_levels", axis = 1, inplace=True)
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low.drop("RRM2B_levels", axis = 1, inplace=True)
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high.loc["mean high"] = high.mean()
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low.loc["mean low"] = low.mean()
# ['INE2', 'GUCA1B', 'PRDM8', 'C10orf81', 'CENPM', 'ADAT3', 'RIMS2', 'NUDT1', 'LONRF2', 'KCNJ8', 'ST6GALNAC5', 'C21orf34', 'MSH5', 'ADH1C', 'UCN', 'SCAMP1', 'NSUN5P1', 'KCND3', 'IL6ST', 'C3orf35', 'MYCN', 'SCN4B', 'SYT14', 'PKIB', 'AGTR1', 'TCP11L2', 'CHCHD10', 'ZNF385B', 'C9orf69', 'ANPEP', 'PRDM16', 'C1orf190', 'ANXA13', 'RHOT2', 'SYBU', 'NR3C1', 'LOC100132287', 'SERPINA5', 'DIRAS1', 'CENPT', 'SEC16B', 'SPRY4', 'RTN4RL1', 'LOC100129637', 'CAPS2', 'DDX39', 'MR1', 'PLXNC1', 'PLIN4', 'SERPINA3', 'CD300LB', 'C19orf6', 'CUBN', 'PTPLAD2', 'LYSMD3', 'AMZ1', 'ARHGEF17', 'PDZRN4', 'NCLN', 'EPAS1', 'TNNC1', 'UBASH3B', 'GSDMB', 'KL', 'GBP1', 'AKAP3', 'MARCH8', 'LOC150776', 'EIF4E3', 'WDR72', 'C4orf34', 'CDH5', 'SDS', 'CD300LF', 'LOC100133669', 'SALL2', 'CD163', 'KITLG', 'NIPAL2', 'MAZ', 'ACER2', 'PGR', 'MFAP3L', 'JAM3', 'RASL12', 'LOC100288778', 'PTN', 'TELO2', 'DACT3', 'STK33', 'KCNS1', 'ATP2A1', 'LOC255167', 'ARHGAP15', 'MTTP', 'P2RY11', 'ADSSL1', 'CD207', 'NFATC2', 'SLC9A7', 'UBL3', 'KCNJ10', 'MND1', 'PIK3AP1', 'MS4A1', 'PI15', 'SPP1', 'PPAPDC1A', 'CNTFR', 'IVL', 'MAGEA12', 'CKMT2', 'GLIPR2', 'CCDC17', 'TWIST1', 'C17orf86', 'LOC338799', 'SLIT3', 'CTSO', 'FGF2', 'CDON', 'GRID1', 'RGS7BP', 'PRODH', 'PILRA', 'VSIG2', 'ZNF702P', 'FCHO2', 'KIAA1199', 'CKMT1B', 'psiTPTE22', 'ZCWPW2', 'PAR5', 'ATP6V0D2', 'C1QTNF2', 'CRTAC1', 'LRRC4C', 'PDE1B', 'C9orf172', 'MRPL55', 'COL6A2', 'PPM1L', 'HOXB9', 'SLC4A4', 'ANO6', 'ZNF787', 'NOP16', 'SPOCK1', 'GMPR', 'PPFIA3', 'WISP2', 'FAM190A', 'CADM1', 'ALKBH6', 'MBNL2', 'APOBEC3G', 'MYOZ1', 'C12orf59', 'SLC2A5', 'COL6A3', 'EPM2A', 'B4GALNT1', 'MRPL41', 'THRB', 'C10orf128', 'C4orf31', 'VEPH1', 'IL27RA', 'ADAMTS12', 'FREM1', 'ABCA6', 'EDN3', 'CD74', 'FLNA', 'MYOZ3', 'PRDM6', 'ELF5', 'CCDC19', 'IGSF10', 'CEMP1', 'ZNF683', 'SMOC2', 'HLA-DRB6', 'CD68', 'CLEC1A', 'DOC2B', 'EYA2', 'PPP1R14D', 'ZNF660', 'LPIN3', 'SCN3B', 'MCTP1', 'SPI1', 'PUS1', 'MSR1', 'VAX2', 'LMOD3', 'DUS1L', 'OSGIN1', 'WDR85', 'AZIN1', 'LCN2', 'TTBK2', 'SLC9A2', 'SECISBP2L', 'S100A8', 'CCL2', 'DENND2C', 'ARRDC3', 'PEG3', 'RPL36A', 'VIM', 'C2orf89', 'SORL1', 'KCND2', 'ATP8B4', 'GREB1', 'C9orf142', 'AHSA2', 'HOMER3', 'CHSY3', 'OR51E2', 'LRRC17', 'COL8A1', 'MAN1C1', 'BYSL', 'EPDR1', 'IL10RA', 'PPM1A', 'HMGA2', 'PHACTR1', 'FMOD', 'TMEM130', 'FBXO32', 'ENPP1', 'ALDH3A1', 'TRMT1', 'EME1', 'PCDHGB1', 'PARP15', 'TNFRSF25', 'CNRIP1', 'SETBP1', 'COL22A1', 'SCARNA12', 'CLIP4', 'LILRA5', 'PQLC3', 'FLT3', 'PRTG', 'FOXF1', 'ANKRD23', 'CASD1', 'SUSD2', 'PKD2', 'POLE', 'SCN4A', 'GRINL1A', 'GPR172B', 'C1orf35', 'HEYL', 'PFDN2', 'SFTA1P', 'LOC653501', 'LGI3', 'MAPK4', 'AMY2B', 'PILRB', 'KLHL14', 'PHYHIPL', 'FCER1G', 'TTC28', 'SIRT6', 'C6orf186', 'TRIM9', 'PSMG3', 'FXYD1', 'COL21A1', 'TPSAB1', 'ZNF831', 'CPEB4', 'SELE', 'ANK2', 'FAM19A2', 'RELL2', 'FZD6', 'HP', 'C9orf140', 'DCDC2', 'LSM7', 'NEB', 'SKA1', 'WDR7', 'CYP2D7P1', 'TMEM155', 'GREB1L', 'FAM161B', 'DCAF12L2', 'PKN3', 'PDE2A', 'SFRS16', 'LOX', 'F13A1', 'SEMA6A', 'CD2', 'C9orf100', 'DUSP9', 'FOXO1', 'SPHK1', 'DAAM1', 'ZNF579', 'DNASE1L2', 'BICC1', 'LOC399959', 'CCDC121', 'MRC1', 'BICD1', 'HPGDS', 'C9orf37', 'NR2F6', 'ZFHX4', 'CCNO', 'PFDN6', 'RAB37', 'MAMDC2', 'UNC13D', 'UPK3BL', 'MAML2', 'GPIHBP1', 'OIT3', 'LOC221442', 'COBRA1', 'LPCAT2', 'SEPT4', 'TNN', 'PHKG2', 'STK3', 'RERGL', 'SPC24', 'CPVL', 'P2RY12', 'TNFSF12', 'ATAD3B', 'EDNRA', 'ITGA8', 'CD37', 'MGC45800', 'FST', 'P4HA3', 'ATG9B', 'SLC14A1', 'CORT', 'TPRN', 'SLAMF1', 'GCNT4', 'RNFT2', 'TMEM170B', 'SPTBN5', 'TRAIP', 'CITED2', 'FHOD3', 'SLC44A4', 'PARK2', 'SKA3', 'ARHGAP6', 'KCNAB1', 'NAP1L2', 'IER5L', 'TXNIP', 'SULF1', 'KIF2C', 'KANK2', 'MPDZ', 'NDOR1', 'MXD3', 'PRSS12', 'ADRB1', 'SLC30A4', 'MAT2B', 'ALPK2', 'NME1-NME2', 'ESPL1', 'MME', 'H2AFX', 'SNED1', 'CYP7B1', 'ACSL1', 'SLAIN1', 'PPFIA4', 'ITGA5', 'PRG2', 'LRFN4', 'ZMAT3', 'ADAMTS6', 'FOXF2', 'KLF10', 'CLIC6', 'ERG', 'CORIN', 'TM6SF1', 'F10', 'MBLAC2', 'ZDHHC2', 'SRL', 'UTP23', 'SPERT', 'PTPRD', 'KLF16', 'PTGFR', 'LOC127841', 'MERTK', 'FAM175A', 'ASB16', 'CENPP', 'GIMAP4', 'HSPB8', 'COL3A1', 'SLC ...
# ---------
# LIHC
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high.drop("RRM2B_levels", axis = 1, inplace=True)
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low.drop("RRM2B_levels", axis = 1, inplace=True)
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high.loc["mean high"] = high.mean()
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low.loc["mean low"] = low.mean()
# ['LCP2', 'ALPK2', 'PRDM8', 'ESPL1', 'MME', 'ADAT3', 'H2AFX', 'AZGP1', 'NUDT1', 'CYP7B1', 'ACSL1', 'TMEM86B', 'SLAIN1', 'C21orf129', 'LONRF2', 'IL1R1', 'C14orf64', 'ST6GALNAC5', 'COL14A1', 'KIT', 'SNURF', 'C4orf12', 'ADH1C', 'KCNB1', 'RHCG', 'ZMAT3', 'ADAMTS6', 'FOXF2', 'SDC2', 'CDCA5', 'SCAMP1', 'KLF10', 'NSUN5P1', 'CLIC6', 'ERG', 'KCND3', 'TM6SF1', 'F10', 'MBLAC2', 'IL6ST', 'FUT6', 'BCL2L12', 'ANKRD29', 'ZDHHC2', 'MYCN', 'XRCC3', 'SCN4B', 'OLR1', 'MYH11', 'PKIB', 'AGTR1', 'UTP23', 'SPERT', 'TCP11L2', 'PTPRD', 'C8orf83', 'MERTK', 'ANPEP', 'CENPP', 'GIMAP4', 'HSPB8', 'COL3A1', 'RNF180', 'EPS8', 'C1orf190', 'SLC16A7', 'TNNI2', 'ANXA13', 'C1orf159', 'PSRC1', 'C20orf135', 'C6orf125', 'SYBU', 'C9orf114', 'EDIL3', 'COLEC12', 'LY9', 'WASH3P', 'FRS2', 'SERPINA5', 'GSTM5', 'HGF', 'RXRG', 'NCAM1', 'ELN', 'FCRL6', 'SEC16B', 'PLCB1', 'CR1', 'SGCD', 'HIST1H2AM', 'SLC25A10', 'KIFC2', 'SPRY4', 'RTN4RL1', 'DRD4', 'MUC4', 'WBSCR17', 'DLX3', 'GJA5', 'CAPS2', 'PRICKLE1', 'RASAL1', 'MR1', 'PLXNC1', 'ROR1', 'GPR171', 'MAN1A1', 'CYP1B1', 'SERPINA3', 'TMEM67', 'KRBA2', 'TMTC1', 'SLIT2', 'DIXDC1', 'CDKL5', 'MIIP', 'PRG4', 'SAC3D1', 'CUBN', 'WNT5A', 'CYSLTR2', 'ESRRG', 'PTPLAD2', 'LYSMD3', 'AMZ1', 'CD48', 'KAT2B', 'C16orf59', 'PRKG1', 'KIF21B', 'PDIA2', 'DTYMK', 'UBASH3B', 'C19orf48', 'LOC339674', 'SAMD3', 'C10orf114', 'GBP1', 'C11orf21', 'SH2D1A', 'LRRC32', 'MARCH8', 'SPRN', 'SIRPG', 'MSC', 'ENPP3', 'CHTF18', 'SIRPB2', 'SNRPA', 'GAB3', 'ZNF252', 'AKAP6', 'ZFPM2', 'C5orf23', 'CDH5', 'SFRP5', 'NAP1L3', 'BMPR2', 'NCOA7', 'SDS', 'SNHG10', 'CD300LF', 'LOC100133669', 'PCDHGB7', 'SIGLEC5', 'CHRDL1', 'PDE10A', 'ENTPD2', 'CD163', 'RAD54L', 'KITLG', 'RAD9A', 'NIPAL2', 'PSAT1', 'ZNF366', 'ACER2', 'TMEM64', 'PTGER3', 'MFAP3L', 'MUSTN1', 'SNORD116-28', 'ANKRD46', 'LOC100288778', 'ABCA8', 'KCNA5', 'C16orf54', 'WDR47', 'CASC5', 'SESN3', 'COL1A1', 'ITK', 'GGTA1', 'CXCL14', 'BNIPL', 'KCNS1', 'PSMC3IP', 'TM4SF18', 'LOC255167', 'C11orf70', 'TLR3', 'LGI2', 'C14orf181', 'SPARCL1', 'ARHGAP15', 'MAP9', 'CYP2U1', 'MTTP', 'NOL12', 'IMPA1', 'P2RY11', 'ZNF699', 'PRR7', 'LOC100271831', 'LCN12', 'ADSSL1', 'C16orf79', 'TLR1', 'NFATC2', 'SLC9A7', 'UBL3', 'KIFC1', 'TBC1D3', 'TERT', 'SCARA5', 'BAALC', 'CPNE7', 'LOXL4', 'SHISA2', 'SV2B', 'HSPB7', 'COMP', 'PIK3AP1', 'MS4A1', 'DPY19L4', 'PI15', 'SPP1', 'ZHX1', 'FNDC1', 'CADM3', 'GFRA2', 'LUM', 'CNTFR', 'ABCC4', 'C6orf174', 'C17orf53', 'SPINK5', 'TOMM40', 'CMYA5', 'BIN2', 'KLHL4', 'ST8SIA4', 'VGLL3', 'QKI', 'SLIT3', 'PGM5', 'C5orf41', 'CTNND2', 'KLRB1', 'CTSO', 'CSF3R', 'FGF2', 'RGS7BP', 'GREM1', 'PRODH', 'CACNB4', 'EFEMP1', 'PILRA', 'SHISA3', 'PAPPA', 'MFAP4', 'RSPO3', 'VSIG2', 'SLC6A17', 'PAPPA2', 'LGR5', 'UBE2W', 'POSTN', 'PRR22', 'CA9', 'NCOA2', 'CDK3', 'PRKAR2B', 'RNASEH2A', 'MS4A2', 'NEK1', 'DOCK4', 'AKAP2', 'FCHO2', 'MDM2', 'KIAA1199', 'ELFN2', 'FAM70A', 'CKMT1B', 'psiTPTE22', 'HSPB2', 'WDR34', 'ICAM4', 'ARHGAP25', 'NKX3-2', 'UGT1A9', 'HYDIN', 'SCN7A', 'ALOX5AP', 'RAB8B', 'CD40LG', 'STAC', 'PAR5', 'FAM128A', 'C2orf65', 'MUC1', 'LACTB2', 'ZNF844', 'ATP6V0D2', 'POLD1', 'SELO', 'FAM195A', 'DNLZ', 'C5orf24', 'PRR16', 'CP', 'CYLD', 'GPR133', 'ICOS', 'MRPL55', 'COL6A2', 'PPM1L', 'SLC4A4', 'ANO6', 'SCPEP1', 'ZNF787', 'CCR1', 'ITPKA', 'CPA3', 'MAT1A', 'TROAP', 'SV2A', 'SPOCK1', 'MYBL2', 'SULT1C4', 'CD84', 'WISP2', 'FAIM3', 'EGFL8', 'SOX6', 'KIF26B', 'C6orf26', 'MBNL2', 'C1QC', 'GAS7', 'APOBEC3G', 'C6orf138', 'CCDC150', 'VEGFC', 'HLA-DPB1', 'ANO5', 'MAPT', 'BTBD16', 'C12orf59', 'CPNE3', 'NALCN', 'HLA-DQB2', 'CES3', 'LRRC45', 'CCPG1', 'COL6A3', 'TLR9', 'USP51', 'LRRK2', 'NSUN5P2', 'GATA5', 'B4GALNT1', 'VTN', 'LSAMP', 'ZGPAT', 'ACSS3', 'KIF22', 'SLC7A7', 'MRPL41', 'PAQR6', 'SERTAD4', 'CHAF1A', 'FPR2', 'TIAF1', 'C7', 'CNTN3', 'FAM110B', 'ATP12A', 'WDR18', 'PIF1', 'LOC653653', 'C10orf128', 'C4orf31', 'VEPH1', 'MAGED4', 'TOX', 'KNDC1', 'CKMT1A', 'RPS6KA5', 'ADAMTS12', 'GPNMB', 'NTN4', 'BTC', 'WWC2', 'EDA2R', 'ABCA6', 'DEPDC6', 'EDN3', 'C1orf186', 'CBX6', 'KCTD12', 'CD74', 'FLNA', 'FAM164A', 'KCNJ5', 'LDB2', 'LHFP', 'ESYT3', 'SH3BP5', 'IGSF10', ...
# ---------
# LUSC
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high.drop("RRM2B_levels", axis = 1, inplace=True)
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low.drop("RRM2B_levels", axis = 1, inplace=True)
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high.loc["mean high"] = high.mean()
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low.loc["mean low"] = low.mean()
# ['LCP2', 'ALPK2', 'PRDM8', 'MME', 'ESPL1', 'ADAT3', 'H2AFX', 'AZGP1', 'NUDT1', 'CYP7B1', 'ACSL1', 'TMEM86B', 'SLAIN1', 'LONRF2', 'IL1R1', 'C14orf64', 'ST6GALNAC5', 'COL14A1', 'KIT', 'SNURF', 'C4orf12', 'ADH1C', 'KCNB1', 'RHCG', 'SDC2', 'FOXF2', 'CDCA5', 'KLF10', 'NSUN5P1', 'CLIC6', 'ERG', 'KCND3', 'TM6SF1', 'F10', 'IL6ST', 'BCL2L12', 'ANKRD29', 'ZDHHC2', 'MYCN', 'XRCC3', 'SCN4B', 'OLR1', 'MYH11', 'PKIB', 'AGTR1', 'SPERT', 'TCP11L2', 'PTPRD', 'C8orf83', 'ANPEP', 'CENPP', 'GIMAP4', 'HSPB8', 'RNF180', 'EPS8', 'C1orf190', 'SLC16A7', 'TNNI2', 'ANXA13', 'C1orf159', 'PSRC1', 'C20orf135', 'C6orf125', 'SYBU', 'C9orf114', 'EDIL3', 'COLEC12', 'LY9', 'WASH3P', 'SERPINA5', 'GSTM5', 'HGF', 'RXRG', 'NCAM1', 'ELN', 'FCRL6', 'CR1', 'SGCD', 'HIST1H2AM', 'SLC25A10', 'KIFC2', 'SPRY4', 'RTN4RL1', 'DRD4', 'MUC4', 'WBSCR17', 'DLX3', 'GJA5', 'CAPS2', 'PRICKLE1', 'RASAL1', 'MR1', 'PLXNC1', 'ROR1', 'GPR171', 'MAN1A1', 'CYP1B1', 'SERPINA3', 'TMEM67', 'SLIT2', 'DIXDC1', 'CDKL5', 'PRG4', 'SAC3D1', 'CUBN', 'WNT5A', 'CYSLTR2', 'ESRRG', 'PTPLAD2', 'LYSMD3', 'AMZ1', 'CD48', 'KAT2B', 'C16orf59', 'PRKG1', 'KIF21B', 'PDIA2', 'DTYMK', 'UBASH3B', 'C19orf48', 'LOC339674', 'SAMD3', 'C10orf114', 'GBP1', 'C11orf21', 'SH2D1A', 'LRRC32', 'MARCH8', 'SPRN', 'ENPP3', 'CHTF18', 'SIRPB2', 'SNRPA', 'GAB3', 'AKAP6', 'ZFPM2', 'C5orf23', 'CDH5', 'SFRP5', 'NAP1L3', 'BMPR2', 'NCOA7', 'SDS', 'SNHG10', 'CD300LF', 'LOC100133669', 'PCDHGB7', 'SIGLEC5', 'CHRDL1', 'PDE10A', 'ENTPD2', 'CD163', 'RAD54L', 'KITLG', 'RAD9A', 'NIPAL2', 'PSAT1', 'ZNF366', 'ACER2', 'TMEM64', 'PTGER3', 'MFAP3L', 'MUSTN1', 'ANKRD46', 'LOC100288778', 'ABCA8', 'KCNA5', 'C16orf54', 'CASC5', 'SESN3', 'COL1A1', 'ITK', 'GGTA1', 'CXCL14', 'KCNS1', 'PSMC3IP', 'TM4SF18', 'C11orf70', 'TLR3', 'LGI2', 'C14orf181', 'SPARCL1', 'ARHGAP15', 'MAP9', 'CYP2U1', 'NOL12', 'IMPA1', 'P2RY11', 'ZNF699', 'PRR7', 'LOC100271831', 'LCN12', 'C16orf79', 'TLR1', 'NFATC2', 'SLC9A7', 'UBL3', 'KIFC1', 'TBC1D3', 'TERT', 'SCARA5', 'BAALC', 'CPNE7', 'LOXL4', 'SV2B', 'HSPB7', 'COMP', 'PIK3AP1', 'MS4A1', 'DPY19L4', 'PI15', 'SPP1', 'ZHX1', 'CADM3', 'GFRA2', 'LUM', 'ABCC4', 'C6orf174', 'C17orf53', 'SPINK5', 'TOMM40', 'BIN2', 'KLHL4', 'ST8SIA4', 'VGLL3', 'QKI', 'SLIT3', 'PGM5', 'C5orf41', 'CTNND2', 'KLRB1', 'CTSO', 'CSF3R', 'FGF2', 'RGS7BP', 'GREM1', 'CACNB4', 'EFEMP1', 'PILRA', 'SHISA3', 'PAPPA', 'MFAP4', 'RSPO3', 'VSIG2', 'LGR5', 'UBE2W', 'POSTN', 'PRR22', 'CA9', 'NCOA2', 'CDK3', 'PRKAR2B', 'RNASEH2A', 'MS4A2', 'DOCK4', 'AKAP2', 'FCHO2', 'ELFN2', 'FAM70A', 'CKMT1B', 'psiTPTE22', 'HSPB2', 'WDR34', 'ICAM4', 'ARHGAP25', 'NKX3-2', 'UGT1A9', 'HYDIN', 'SCN7A', 'ALOX5AP', 'RAB8B', 'STAC', 'PAR5', 'FAM128A', 'C2orf65', 'MUC1', 'LACTB2', 'ZNF844', 'ATP6V0D2', 'POLD1', 'SELO', 'FAM195A', 'DNLZ', 'C5orf24', 'PRR16', 'CP', 'CYLD', 'GPR133', 'ICOS', 'MRPL55', 'MAT2B', 'SLC4A4', 'ANO6', 'ZNF787', 'CCR1', 'ITPKA', 'CPA3', 'TROAP', 'SV2A', 'SPOCK1', 'MYBL2', 'SULT1C4', 'CD84', 'WISP2', 'FAIM3', 'EGFL8', 'KIF26B', 'C6orf26', 'MBNL2', 'C1QC', 'GAS7', 'APOBEC3G', 'C6orf138', 'CCDC150', 'VEGFC', 'HLA-DPB1', 'ANO5', 'BTBD16', 'CPNE3', 'C12orf59', 'NALCN', 'HLA-DQB2', 'LRRC45', 'CCPG1', 'USP51', 'LRRK2', 'NSUN5P2', 'GATA5', 'B4GALNT1', 'VTN', 'LSAMP', 'ZGPAT', 'ACSS3', 'KIF22', 'SLC7A7', 'MRPL41', 'PAQR6', 'CHAF1A', 'FPR2', 'C7', 'CNTN3', 'FAM110B', 'ATP12A', 'WDR18', 'PIF1', 'LOC653653', 'C10orf128', 'C4orf31', 'VEPH1', 'MAGED4', 'TOX', 'KNDC1', 'CKMT1A', 'ADAMTS12', 'NTN4', 'BTC', 'WWC2', 'EDA2R', 'ABCA6', 'DEPDC6', 'EDN3', 'C1orf186', 'KCTD12', 'CD74', 'FAM164A', 'KCNJ5', 'LDB2', 'LHFP', 'ESYT3', 'SH3BP5', 'IGSF10', 'SIGLEC1', 'KCNQ3', 'WDR17', 'SMOC2', 'HLA-DRB6', 'MOXD1', 'CD68', 'PLEKHF2', 'CLEC1A', 'TUBB4', 'BMP7', 'SDCBP', 'BMP5', 'EYA2', 'C8orf84', 'ZMYND19', 'PTX3', 'HCLS1', 'C20orf151', 'HIPK3', 'OLFML1', 'HVCN1', 'RAB30', 'ZDHHC12', 'MCTP1', 'OR2B6', 'NFAM1', 'STAM2', 'ASF1B', 'FASTK', 'FRZB', 'PTGDS', 'SPI1', 'MSR1', 'MMP14', 'KIAA1755', 'ZNF704', 'VAX2', 'PCMTD1', 'AURKB', 'OSTM1', 'ABI3BP', 'MCM5', 'GPR82', 'RASGRP4', 'QRICH2', 'OSGIN1', 'WDR85', 'SNORD116-20 ...
# ---------
# OV
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high.drop("RRM2B_levels", axis = 1, inplace=True)
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low.drop("RRM2B_levels", axis = 1, inplace=True)
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high.loc["mean high"] = high.mean()
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low.loc["mean low"] = low.mean()
# ['LCP2', 'ALPK2', 'PRDM8', 'MME', 'ESPL1', 'AZGP1', 'CYP7B1', 'ACSL1', 'LONRF2', 'IL1R1', 'C14orf64', 'ST6GALNAC5', 'SDC2', 'FOXF2', 'KLF10', 'NSUN5P1', 'CLIC6', 'ERG', 'TM6SF1', 'F10', 'IL6ST', 'ANKRD29', 'MYCN', 'XRCC3', 'OLR1', 'MYH11', 'AGTR1', 'SPERT', 'PTPRD', 'C8orf83', 'ANPEP', 'GIMAP4', 'HSPB8', 'SLC16A7', 'C1orf159', 'PSRC1', 'SYBU', 'EDIL3', 'COLEC12', 'LY9', 'WASH3P', 'GSTM5', 'HGF', 'RXRG', 'FCRL6', 'CR1', 'SGCD', 'KIFC2', 'SPRY4', 'RTN4RL1', 'DRD4', 'MUC4', 'WBSCR17', 'DLX3', 'GJA5', 'PRICKLE1', 'PLXNC1', 'GPR171', 'MAN1A1', 'CYP1B1', 'TMEM67', 'CDKL5', 'PRG4', 'CYSLTR2', 'LYSMD3', 'AMZ1', 'CD48', 'KAT2B', 'C16orf59', 'PRKG1', 'PDIA2', 'UBASH3B', 'C19orf48', 'LOC339674', 'SAMD3', 'C10orf114', 'C11orf21', 'SH2D1A', 'LRRC32', 'ENPP3', 'CHTF18', 'SIRPB2', 'SNRPA', 'GAB3', 'CDH5', 'SFRP5', 'NCOA7', 'SNHG10', 'CD300LF', 'PCDHGB7', 'SIGLEC5', 'PDE10A', 'CD163', 'RAD54L', 'RAD9A', 'NIPAL2', 'TMEM64', 'PTGER3', 'MFAP3L', 'ANKRD46', 'LOC100288778', 'C16orf54', 'SESN3', 'COL1A1', 'ITK', 'GGTA1', 'CXCL14', 'KCNS1', 'C14orf181', 'SPARCL1', 'ARHGAP15', 'IMPA1', 'TLR1', 'NFATC2', 'UBL3', 'KIFC1', 'TERT', 'BAALC', 'LOXL4', 'SV2B', 'COMP', 'PIK3AP1', 'DPY19L4', 'PI15', 'SPP1', 'ZHX1', 'LUM', 'SPINK5', 'BIN2', 'KLHL4', 'ST8SIA4', 'VGLL3', 'SLIT3', 'C5orf41', 'KLRB1', 'CTSO', 'RGS7BP', 'GREM1', 'CACNB4', 'EFEMP1', 'SHISA3', 'PAPPA', 'VSIG2', 'LGR5', 'UBE2W', 'POSTN', 'CA9', 'NCOA2', 'CDK3', 'RNASEH2A', 'MS4A2', 'DOCK4', 'FCHO2', 'ELFN2', 'CKMT1B', 'psiTPTE22', 'ICAM4', 'NKX3-2', 'HYDIN', 'SCN7A', 'ALOX5AP', 'C2orf65', 'FAM128A', 'MUC1', 'LACTB2', 'ATP6V0D2', 'POLD1', 'PRR16', 'CP', 'GPR133', 'ICOS', 'ZNF787', 'CCR1', 'CPA3', 'TROAP', 'SPOCK1', 'MYBL2', 'SULT1C4', 'CD84', 'WISP2', 'FAIM3', 'EGFL8', 'KIF26B', 'C6orf26', 'C1QC', 'GAS7', 'C6orf138', 'CCDC150', 'HLA-DPB1', 'BTBD16', 'CPNE3', 'NALCN', 'C12orf59', 'HLA-DQB2', 'CCPG1', 'LRRK2', 'NSUN5P2', 'GATA5', 'LSAMP', 'SLC7A7', 'PAQR6', 'CHAF1A', 'FPR2', 'FAM110B', 'ATP12A', 'WDR18', 'PIF1', 'C10orf128', 'C4orf31', 'MAGED4', 'TOX', 'KNDC1', 'CKMT1A', 'ADAMTS12', 'NTN4', 'BTC', 'EDA2R', 'ABCA6', 'DEPDC6', 'EDN3', 'C1orf186', 'KCTD12', 'CD74', 'LDB2', 'LHFP', 'SIGLEC1', 'WDR17', 'SMOC2', 'MOXD1', 'CD68', 'PLEKHF2', 'CLEC1A', 'TUBB4', 'BMP7', 'EYA2', 'PTX3', 'HCLS1', 'C20orf151', 'HIPK3', 'OLFML1', 'MCTP1', 'OR2B6', 'NFAM1', 'ASF1B', 'FRZB', 'PTGDS', 'SPI1', 'MSR1', 'MMP14', 'PCMTD1', 'AURKB', 'ABI3BP', 'GPR82', 'RASGRP4', 'NTNG2', 'TRO', 'AZIN1', 'C10orf10', 'RAB27B', 'PDE1A', 'HK3', 'MYL3', 'CCL2', 'YTHDF3', 'COL4A4', 'RRM2B', 'OXR1', 'TNFAIP6', 'ATP8B4', 'HSPBP1', 'PSMG4', 'CMAH', 'ARAP2', 'HAUS8', 'AR', 'EPHA3', 'ITGB2', 'PHLDA2', 'LRMP', 'SGMS1', 'CHSY3', 'COL8A1', 'GPR34', 'EPDR1', 'IL16', 'IL10', 'ZNF205', 'NEK7', 'B4GALNT4', 'PTGER2', 'IL10RA', 'RASSF8', 'MUM1L1', 'HMGA2', 'PHACTR1', 'PKHD1L1', 'TRIM22', 'RCAN2', 'EGR3', 'WWP1', 'CDT1', 'FMOD', 'TFEC', 'TMEM200C', 'GIMAP7', 'OLFML2B', 'ZNF703', 'KLHL6', 'ALDH3A1', 'ZNF692', 'CCNB2', 'PARP15', 'C1QB', 'CD96', 'COL22A1', 'KAL1', 'E2F1', 'ITGB3', 'KLHL31', 'PLAC9', 'S100B', 'EGR2', 'CYBB', 'PQLC3', 'ZNF789', 'CSMD2', 'FOXF1', 'TLR7', 'GZMK', 'SUSD2', 'PPAP2C', 'LMOD1', 'RGS5', 'POLE', 'CASS4', 'RNF208', 'ADAMTSL3', 'UBE2C', 'PLCL1', 'MAPK4', 'CNTN1', 'TRPV2', 'BIRC5', 'FAM23A', 'LILRA6', 'FGF7', 'C8orf37', 'TMEM156', 'GIMAP8', 'FCER1G', 'AMH', 'EVC', 'SLC16A12', 'TRIM9', 'GFPT2', 'FLI1', 'ANGPTL1', 'FGR', 'FXYD1', 'TPSAB1', 'TACC3', 'NUDT8', 'ZNF831', 'CPEB4', 'GJA1', 'FGL2', 'HAVCR2', 'SELE', 'PRKCB', 'FMO2', 'HAS2', 'CCL13', 'ZP3', 'CBLC', 'SELPLG', 'HP', 'ANKRD45', 'UBE2S', 'ATP10A', 'SPAG5', 'KIAA0748', 'CCL22', 'CYP2D7P1', 'EPHB6', 'LRRC25', 'PRKCQ', 'CX3CR1', 'SFRS16', 'RANBP3L', 'EFR3A', 'SAMSN1', 'LOX', 'UNC5C', 'F13A1', 'PLAU', 'CDCA3', 'ADH1B', 'CD2', 'PMP22', 'SLFN5', 'MAGEA6', 'UPK3B', 'ITGA9', 'MS4A14', 'MATN3', 'ZNF579', 'BICC1', 'MARCH1', 'PKIA', 'TRAM1', 'MRC1', 'HPGDS', 'CPEB3', 'PAFAH1B3', 'CPM', 'FAM38B', 'HSPB6', 'NR2F6', 'ZFHX4', 'CCL19', 'NR4A3', 'MAMDC2', 'DCN', 'PTPN5', 'GLDC', 'WNT2', 'C7orf27', 'FPR1', 'CD ...
# ---------
# BRCA
# ['PRDM8', 'MME', 'AZGP1', 'LONRF2', 'C14orf64', 'FOXF2', 'KLF10', 'NSUN5P1', 'CLIC6', 'TM6SF1', 'F10', 'IL6ST', 'ANKRD29', 'MYCN', 'XRCC3', 'OLR1', 'MYH11', 'AGTR1', 'PTPRD', 'C8orf83', 'ANPEP', 'HSPB8', 'SLC16A7', 'C1orf159', 'PSRC1', 'SYBU', 'EDIL3', 'COLEC12', 'LY9', 'WASH3P', 'GSTM5', 'HGF', 'FCRL6', 'SGCD', 'DRD4', 'MUC4', 'WBSCR17', 'PRICKLE1', 'PLXNC1', 'GPR171', 'MAN1A1', 'TMEM67', 'CDKL5', 'PRG4', 'CYSLTR2', 'LYSMD3', 'AMZ1', 'CD48', 'KAT2B', 'C16orf59', 'PRKG1', 'PDIA2', 'C19orf48', 'LOC339674', 'SAMD3', 'C10orf114', 'C11orf21', 'SH2D1A', 'ENPP3', 'CHTF18', 'SNRPA', 'SFRP5', 'NCOA7', 'SNHG10', 'PCDHGB7', 'PDE10A', 'RAD54L', 'RAD9A', 'NIPAL2', 'TMEM64', 'PTGER3', 'MFAP3L', 'ANKRD46', 'LOC100288778', 'C16orf54', 'SESN3', 'ITK', 'GGTA1', 'KCNS1', 'C14orf181', 'IMPA1', 'NFATC2', 'UBL3', 'KIFC1', 'TERT', 'BAALC', 'LOXL4', 'SV2B', 'DPY19L4', 'PI15', 'SPP1', 'ZHX1', 'LUM', 'SPINK5', 'BIN2', 'KLHL4', 'VGLL3', 'C5orf41', 'KLRB1', 'CTSO', 'GREM1', 'CACNB4', 'SHISA3', 'PAPPA', 'VSIG2', 'UBE2W', 'POSTN', 'CA9', 'NCOA2', 'CDK3', 'RNASEH2A', 'MS4A2', 'DOCK4', 'FCHO2', 'ELFN2', 'psiTPTE22', 'ICAM4', 'SCN7A', 'C2orf65', 'FAM128A', 'MUC1', 'LACTB2', 'ATP6V0D2', 'POLD1', 'CP', 'ICOS', 'ZNF787', 'CPA3', 'TROAP', 'SPOCK1', 'MYBL2', 'CD84', 'WISP2', 'EGFL8', 'C6orf26', 'C1QC', 'C6orf138', 'CCDC150', 'HLA-DPB1', 'BTBD16', 'CPNE3', 'HLA-DQB2', 'CCPG1', 'LRRK2', 'NSUN5P2', 'GATA5', 'PAQR6', 'CHAF1A', 'FAM110B', 'WDR18', 'PIF1', 'MAGED4', 'C4orf31', 'TOX', 'KNDC1', 'ADAMTS12', 'BTC', 'EDA2R', 'DEPDC6', 'EDN3', 'C1orf186', 'CD74', 'WDR17', 'SMOC2', 'PLEKHF2', 'CLEC1A', 'TUBB4', 'EYA2', 'PTX3', 'HCLS1', 'C20orf151', 'HIPK3', 'MCTP1', 'OR2B6', 'NFAM1', 'PTGDS', 'SPI1', 'MSR1', 'MMP14', 'PCMTD1', 'AURKB', 'GPR82', 'NTNG2', 'AZIN1', 'C10orf10', 'RAB27B', 'HK3', 'MYL3', 'CCL2', 'YTHDF3', 'COL4A4', 'RRM2B', 'OXR1', 'HSPBP1', 'PSMG4', 'CMAH', 'HAUS8', 'AR', 'EPHA3', 'ITGB2', 'PHLDA2', 'CHSY3', 'COL8A1', 'GPR34', 'ZNF205', 'NEK7', 'B4GALNT4', 'PTGER2', 'RASSF8', 'MUM1L1', 'EGR3', 'WWP1', 'CDT1', 'FMOD', 'TFEC', 'TMEM200C', 'GIMAP7', 'ZNF703', 'ALDH3A1', 'ZNF692', 'C1QB', 'CD96', 'COL22A1', 'KAL1', 'ITGB3', 'KLHL31', 'PLAC9', 'S100B', 'EGR2', 'CYBB', 'PQLC3', 'ZNF789', 'CSMD2', 'TLR7', 'GZMK', 'SUSD2', 'PPAP2C', 'LMOD1', 'RGS5', 'RNF208', 'ADAMTSL3', 'MAPK4', 'CNTN1', 'TRPV2', 'C8orf37', 'AMH', 'TRIM9', 'FGR', 'FXYD1', 'TACC3', 'NUDT8', 'ZNF831', 'CPEB4', 'GJA1', 'FMO2', 'HAS2', 'CCL13', 'ZP3', 'CBLC', 'SELPLG', 'HP', 'ANKRD45', 'UBE2S', 'CCL22', 'KIAA0748', 'CYP2D7P1', 'EPHB6', 'PRKCQ', 'CX3CR1', 'SFRS16', 'RANBP3L', 'EFR3A', 'UNC5C', 'F13A1', 'CDCA3', 'ADH1B', 'CD2', 'SLFN5', 'UPK3B', 'MATN3', 'ZNF579', 'BICC1', 'MARCH1', 'TRAM1', 'PAFAH1B3', 'CPEB3', 'FAM38B', 'HSPB6', 'NR2F6', 'ZFHX4', 'CCL19', 'PTPN5', 'GLDC', 'C7orf27', 'CDC20', 'MITF', 'UPK3BL', 'USH1C', 'WASH7P', 'OIT3', 'SUCNR1', 'PIK3CG', 'FBN2', 'ENO3', 'H19', 'SOX5', 'STK3', 'VASN', 'TACC1', 'EDNRA', 'ITGA8', 'CD37', 'FST', 'CCHCR1', 'CORT', 'AGER', 'SLAMF1', 'FOXP3', 'GCNT4', 'ZFAND1', 'CHGB', 'TRAIP', 'DCST2', 'SASH3', 'LEPROT', 'NME5', 'PPP1R1B', 'NASP', 'PDLIM3', 'VPS13B', 'TRIM11', 'ZNF365', 'MPDZ', 'PTAFR', 'CD40LG']
# ---------
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high.drop("RRM2B_levels", axis = 1, inplace=True)
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low.drop("RRM2B_levels", axis = 1, inplace=True)
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high.loc["mean high"] = high.mean()
# /var/folders/mp/lfr86vf57gzgqs4tr6qd5bs80000gn/T/ipykernel_27131/3381976129.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low.loc["mean low"] = low.mean()

# %%
list(overlap)
# Out:
# ['PRDM8',
#  'MME',
#  'AZGP1',
#  'LONRF2',
#  'C14orf64',
#  'FOXF2',
#  'KLF10',
#  'NSUN5P1',
#  'CLIC6',
#  'TM6SF1',
#  'F10',
#  'IL6ST',
#  'ANKRD29',
#  'MYCN',
#  'XRCC3',
#  'OLR1',
#  'MYH11',
#  'AGTR1',
#  'PTPRD',
#  'C8orf83',
#  'ANPEP',
#  'HSPB8',
#  'SLC16A7',
#  'C1orf159',
#  'PSRC1',
#  'SYBU',
#  'EDIL3',
#  'COLEC12',
#  'LY9',
#  'WASH3P',
#  'GSTM5',
#  'HGF',
#  'FCRL6',
#  'SGCD',
#  'DRD4',
#  'MUC4',
#  'WBSCR17',
#  'PRICKLE1',
#  'PLXNC1',
#  'GPR171',
#  'MAN1A1',
#  'TMEM67',
#  'CDKL5',
#  'PRG4',
#  'CYSLTR2',
#  'LYSMD3',
#  'AMZ1',
#  'CD48',
#  'KAT2B',
#  'C16orf59',
#  'PRKG1',
#  'PDIA2',
#  'C19orf48',
#  'LOC339674',
#  'SAMD3',
#  'C10orf114',
#  'C11orf21',
#  'SH2D1A',
#  'ENPP3',
#  'CHTF18',
#  'SNRPA',
#  'SFRP5',
#  'NCOA7',
#  'SNHG10',
#  'PCDHGB7',
#  'PDE10A',
#  'RAD54L',
#  'RAD9A',
#  'NIPAL2',
#  'TMEM64',
#  'PTGER3',
#  'MFAP3L',
#  'ANKRD46',
#  'LOC100288778',
#  'C16orf54',
#  'SESN3',
#  'ITK',
#  'GGTA1',
#  'KCNS1',
#  'C14orf181',
#  'IMPA1',
#  'NFATC2',
#  'UBL3',
#  'KIFC1',
#  'TERT',
#  'BAALC',
#  'LOXL4',
#  'SV2B',
#  'DPY19L4',
#  'PI15',
#  'SPP1',
#  'ZHX1',
#  'LUM',
#  'SPINK5',
#  'BIN2',
#  'KLHL4',
#  'VGLL3',
#  'C5orf41',
#  'KLRB1',
#  'CTSO',
#  'GREM1',
#  'CACNB4',
#  'SHISA3',
#  'PAPPA',
#  'VSIG2',
#  'UBE2W',
#  'POSTN',
#  'CA9',
#  'NCOA2',
#  'CDK3',
#  'RNASEH2A',
#  'MS4A2',
#  'DOCK4',
#  'FCHO2',
#  'ELFN2',
#  'psiTPTE22',
#  'ICAM4',
#  'SCN7A',
#  'C2orf65',
#  'FAM128A',
#  'MUC1',
#  'LACTB2',
#  'ATP6V0D2',
#  'POLD1',
#  'CP',
#  'ICOS',
#  'ZNF787',
#  'CPA3',
#  'TROAP',
#  'SPOCK1',
#  'MYBL2',
#  'CD84',
#  'WISP2',
#  'EGFL8',
#  'C6orf26',
#  'C1QC',
#  'C6orf138',
#  'CCDC150',
#  'HLA-DPB1',
#  'BTBD16',
#  'CPNE3',
#  'HLA-DQB2',
#  'CCPG1',
#  'LRRK2',
#  'NSUN5P2',
#  'GATA5',
#  'PAQR6',
#  'CHAF1A',
#  'FAM110B',
#  'WDR18',
#  'PIF1',
#  'MAGED4',
#  'C4orf31',
#  'TOX',
#  'KNDC1',
#  'ADAMTS12',
#  'BTC',
#  'EDA2R',
#  'DEPDC6',
#  'EDN3',
#  'C1orf186',
#  'CD74',
#  'WDR17',
#  'SMOC2',
#  'PLEKHF2',
#  'CLEC1A',
#  'TUBB4',
#  'EYA2',
#  'PTX3',
#  'HCLS1',
#  'C20orf151',
#  'HIPK3',
#  'MCTP1',
#  'OR2B6',
#  'NFAM1',
#  'PTGDS',
#  'SPI1',
#  'MSR1',
#  'MMP14',
#  'PCMTD1',
#  'AURKB',
#  'GPR82',
#  'NTNG2',
#  'AZIN1',
#  'C10orf10',
#  'RAB27B',
#  'HK3',
#  'MYL3',
#  'CCL2',
#  'YTHDF3',
#  'COL4A4',
#  'RRM2B',
#  'OXR1',
#  'HSPBP1',
#  'PSMG4',
#  'CMAH',
#  'HAUS8',
#  'AR',
#  'EPHA3',
#  'ITGB2',
#  'PHLDA2',
#  'CHSY3',
#  'COL8A1',
#  'GPR34',
#  'ZNF205',
#  'NEK7',
#  'B4GALNT4',
#  'PTGER2',
#  'RASSF8',
#  'MUM1L1',
#  'EGR3',
#  'WWP1',
#  'CDT1',
#  'FMOD',
#  'TFEC',
#  'TMEM200C',
#  'GIMAP7',
#  'ZNF703',
#  'ALDH3A1',
#  'ZNF692',
#  'C1QB',
#  'CD96',
#  'COL22A1',
#  'KAL1',
#  'ITGB3',
#  'KLHL31',
#  'PLAC9',
#  'S100B',
#  'EGR2',
#  'CYBB',
#  'PQLC3',
#  'ZNF789',
#  'CSMD2',
#  'TLR7',
#  'GZMK',
#  'SUSD2',
#  'PPAP2C',
#  'LMOD1',
#  'RGS5',
#  'RNF208',
#  'ADAMTSL3',
#  'MAPK4',
#  'CNTN1',
#  'TRPV2',
#  'C8orf37',
#  'AMH',
#  'TRIM9',
#  'FGR',
#  'FXYD1',
#  'TACC3',
#  'NUDT8',
#  'ZNF831',
#  'CPEB4',
#  'GJA1',
#  'FMO2',
#  'HAS2',
#  'CCL13',
#  'ZP3',
#  'CBLC',
#  'SELPLG',
#  'HP',
#  'ANKRD45',
#  'UBE2S',
#  'CCL22',
#  'KIAA0748',
#  'CYP2D7P1',
#  'EPHB6',
#  'PRKCQ',
#  'CX3CR1',
#  'SFRS16',
#  'RANBP3L',
#  'EFR3A',
#  'UNC5C',
#  'F13A1',
#  'CDCA3',
#  'ADH1B',
#  'CD2',
#  'SLFN5',
#  'UPK3B',
#  'MATN3',
#  'ZNF579',
#  'BICC1',
#  'MARCH1',
#  'TRAM1',
#  'PAFAH1B3',
#  'CPEB3',
#  'FAM38B',
#  'HSPB6',
#  'NR2F6',
#  'ZFHX4',
#  'CCL19',
#  'PTPN5',
#  'GLDC',
#  'C7orf27',
#  'CDC20',
#  'MITF',
#  'UPK3BL',
#  'USH1C',
#  'WASH7P',
#  'OIT3',
#  'SUCNR1',
#  'PIK3CG',
#  'FBN2',
#  'ENO3',
#  'H19',
#  'SOX5',
#  'STK3',
#  'VASN',
#  'TACC1',
#  'EDNRA',
#  'ITGA8',
#  'CD37',
#  'FST',
#  'CCHCR1',
#  'CORT',
#  'AGER',
#  'SLAMF1',
#  'FOXP3',
#  'GCNT4',
#  'ZFAND1',
#  'CHGB',
#  'TRAIP',
#  'DCST2',
#  'SASH3',
#  'LEPROT',
#  'NME5',
#  'PPP1R1B',
#  'NASP',
#  'PDLIM3',
#  'VPS13B',
#  'TRIM11',
#  'ZNF365',
#  'MPDZ',
#  'PTAFR',
#  'CD40LG']

# %%
with open('string analysis.csv', 'w') as f:
    
    write = csv.writer(f)
    write.writerow(list(overlap))

# %%
df = df.T

iqr = df["TP53"].describe()

# bin the patients into quartiles based on G6PD expression
df["TP53 levels"] = pd.cut(df["TP53"],
                bins=[ iqr["min"], iqr["25%"], iqr["75%"], iqr["max"]],
                labels=["Bottom 25%", "-", "Top 25%"])

df.drop(df.loc[df["TP53 levels"]=="-"].index, inplace=True)
df.head()

# %%
colData = df[["TP53 levels"]]
countData = df.drop(["TP53 levels"], axis = 1)
countData = countData.T
countData.head()

# %%
colData

# %%
countData.to_csv('countData.csv')
colData.to_csv('colData.csv')

# %%
ls = df.index.to_list()
ls2 = []

substring = "?|"
count = 0
for i in ls:
    if substring in i:
        count+=1
        ls2.append(i)

print(count)
print(ls2)
